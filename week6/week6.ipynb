# %%
import nltk
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
text6.concordance("holy")
# Out:
# Displaying 25 of 26 matches:
# [ angels sing ] Arthur , this is the Holy Grail . Look well , Arthur , for it
# rpose , Arthur ... the quest for the Holy Grail . [ boom ] [ singing stops ] L
#  he can join us in our quest for the Holy Grail . FRENCH GUARD : Well , I ' ll
# gy was required if the quest for the Holy Grail were to be brought to a succes
# GALAHAD : You are the keepers of the Holy Grail ? ZOOT : The what ? GALAHAD :
# CELOT : No , we ' ve got to find the Holy Grail . Come on ! GALAHAD : Oh , let
# uld be the sign that leads us to the Holy Grail ! Brave , brave Concorde , you
# ung people in the joyful bond of the holy wedlock . Unfortunately , one of the
# ' ve not given up your quest for the Holy Grail ? MINSTREL : [ singing ] He is
#  TIM : I do . [ zoosh ] You seek the Holy Grail ! ARTHUR : That is our quest .
# , we ' re -- we ' re looking for the Holy Grail . Our quest is to find the Hol
# ...

# %%
text6.similar("holy")
# Out:
# the real icy

# %%
text2.common_contexts(["and","the"])
# Out:
# ,_very ,_elegance ,_two ;_only by_bye ,_beginning ,_more ,_colonel
# ,_most ,_next ,_miss ._lady ,_gratitude

# %%
text6.dispersion_plot(["holy", "grail", "arthur", "seek", "quest"])

# %% [markdown]
# * Explain in your own words what aspect of language lexical diversity describes.

# %% [markdown]
# This i a measure of the how varied the vocabulary in some text corpus is. If many different words are used in a text and they are not repeated. Then it is highly lexically diverse.

# %% [markdown]
# * Create frequency distributions for text2, including the cumulative frequency plot for the 75 most common words.

# %%
frequency_distribution = FreqDist(text2)

# %%
plt.figure(figsize=(15,10))
frequency_distribution.plot(75,cumulative=True)

# %% [markdown]
# * What is a bigram? How does it relate to collocations. Explain in your own words.

# %% [markdown]
# A bigram is the sequences of two words that are adjacent to each other in some text.
#
# Collocations are words that are often adjacent to each other. Therefore Collocations can be seen as frequently accuring bigrams.

# %% [markdown]
# Work through ex 2-12 in NLPP's section 1.8.

# %% [markdown]
# * Given an alphabet of 26 letters, there are 26 to the power 10, or 26 ** 10, ten-letter strings we can form. That works out to 141167095653376L (the L at the end just indicates that this is Python's long-number format). How many hundred-letter strings are possible?

# %%
26**100
# Out:
# 3142930641582938830174357788501626427282669988762475256374173175398995908420104023465432599069702289330964075081611719197835869803511992549376

# %% [markdown]
# * The Python multiplication operation can be applied to lists. What happens when you type ['Monty', 'Python'] * 20, or 3 * sent1?
#
# Answer: The list with the two elements are created 20 times and appended together

# %%
['Monty','Python'] * 2
# Out:
# ['Monty', 'Python', 'Monty', 'Python']

# %% [markdown]
# * Review 1.1 on computing with language. How many words are there in text2? How many distinct words are there?

# %%
# Number of distinct words
len(set(text2))
# Out:
# 6833

# %%
# Number of words in text2
len(text2)
# Out:
# 141576

# %% [markdown]
# * Compare the lexical diversity scores for humor and romance fiction in 1.1. Which genre is more lexically diverse?

# %% [markdown]
# Humor = 6.4
# Fiction romance = 8.3
#
#
# Fiction romance is more lexically diverse

# %% [markdown]
# * Produce a dispersion plot of the four main protagonists in Sense and Sensibility: Elinor, Marianne, Edward, and Willoughby. What can you observe about the different roles played by the males and females in this novel? Can you identify the couples?

# %%
text2.dispersion_plot(["Elinor", "Marianne", "Edward", "Willoughby"])

# %% [markdown]
# It looks like Marianne and Willoughby are mention in the same intensity in some areas, which could suggest they are a couple.
#
# Its not really clear if Elinor and Edward are a couple.

# %% [markdown]
# * Find the collocations in text5.

# %%
text5.collocations()
# Out:
# wanna chat; PART JOIN; MODE #14-19teens; JOIN PART; PART PART;
# cute.-ass MP3; MP3 player; JOIN JOIN; times .. .; ACTION watches; guys
# wanna; song lasts; last night; ACTION sits; -...)...- S.M.R.; Lime
# Player; Player 12%; dont know; lez gurls; long time

# %% [markdown]
# * Consider the following Python expression: len(set(text4)). State the purpose of this expression. Describe the two steps involved in performing this computation.
#
#     1. converting text4 into a set this removes duplicate tokens.
#     2. finding the length of the set

# %% [markdown]
# * Review 1.2 on lists and strings.
#     * Define a string and assign it to a variable, e.g., my_string = 'My String' (but put something more interesting in the string). Print the contents of this variable in two ways, first by simply typing the variable name and pressing enter, then by using the print statement.

# %%
my_string = "My String"
my_string
# Out:
# 'My String'

# %%
print(my_string)
# Out:
# My String

# %%
my_string + my_string
# Out:
# 'My StringMy String'

# %%
' '.join([my_string] * 3)
# Out:
# 'My String My String My String'

# %% [markdown]
# * Define a variable my_sent to be a list of words, using the syntax my_sent = ["My", "sent"] (but with your own words, or a favorite saying).

# %%
my_sent = ["O","M","G"]

# %%
" ".join(my_sent)
# Out:
# 'O M G'

# %%
" ".join(my_sent).split(" ")
# Out:
# ['O', 'M', 'G']

# %% [markdown]
# * Define several variables containing lists of words, e.g., phrase1, phrase2, and so on. Join them together in various combinations (using the plus operator) to form whole sentences. What is the relationship between len(phrase1 + phrase2) and len(phrase1) + len(phrase2)?
#
# They are the same

# %%
phrase1 = ["Hello", "World"]
phrase2 = ["How", "Are", "You"]
sentence = phrase1 + phrase2
len(sentence)
# Out:
# 5

# %%
len(phrase1 + phrase2)
# Out:
# 5

# %%
len(phrase1) + len(phrase2)
# Out:
# 5

# %% [markdown]
# *  Consider the following two expressions, which have the same value. Which one will typically be more relevant in NLP? Why?

# %%
"Monty Python"[6:12]
# Out:
# 'Python'

# %%
["Monty", "Python"][1]
# Out:
# 'Python'

# %% [markdown]
# I hope the second is more relevant, because it does not make sence to have substrings of words, because the characters in a word should not be seen seperatly from the word they are in. In this case its to seperate words Monty and Python. So it makes sense to have them as seperate tokens.

# %% [markdown]
# * Work through exercise 15, 17, 19, 22, 23, 26, 27, 28 in section 1.8.

# %% [markdown]
# * 15 Review the discussion of conditionals in 1.4. Find all words in the Chat Corpus (text5) starting with the letter b. Show them in alphabetical order.

# %%
sorted([word for word in set(text2) if word.startswith("b")])
# Out:
# ['baby',
#  'bachelor',
#  'back',
#  'backwardness',
#  'backwards',
#  'bad',
#  'badness',
#  'bags',
#  'ball',
#  'balls',
#  'band',
#  'banditti',
#  'banish',
#  'banished',
#  'bank',
#  'banker',
#  'banns',
#  'barbarous',
#  'barbarously',
#  'bargain',
#  'barouche',
#  'barouches',
#  'bashful',
#  'basis',
#  'basket',
#  'bathed',
#  'be',
#  'beamed',
#  'bear',
#  'bearing',
#  'bears',
#  'beasts',
#  'beat',
#  'beau',
#  'beauties',
#  'beautiful',
#  'beautifully',
#  'beauty',
#  'beaux',
#  'became',
#  'because',
#  'become',
#  'becoming',
#  'bed',
#  'bedchamber',
#  'bedroom',
#  'bedrooms',
#  'beds',
#  'bee',
#  'beef',
#  'been',
#  'befall',
#  'befallen',
#  'befalls',
#  'befell',
#  'before',
#  'beg',
#  'began',
#  'begged',
#  'begging',
#  'begin',
#  'beginning',
#  'begins',
#  'begun',
#  'behave',
#  'behaved',
#  'behaviour',
#  'beheld',
#  'behind',
#  'behold',
#  'beholding',
#  'being',
#  'beings',
#  'belief',
#  'believe',
# ...

# %% [markdown]
# * 17 Use text9.index() to find the index of the word sunset. You'll need to insert this word as an argument between the parentheses. By a process of trial and error, find the slice for the complete sentence that contains this word.

# %%
text9.index("sunset")
# Out:
# 629

# %%
" ".join(text9[613:644])
# Out:
# 'CHAPTER I THE TWO POETS OF SAFFRON PARK THE suburb of Saffron Park lay on the sunset side of London , as red and ragged as a cloud of sunset .'

# %% [markdown]
# * 19 What is the difference between the following two lines? Which one will give a larger value? Will this be the case for other texts?

# %%
# This line makes the text into a set on list that hass all words set to lower case. Then sort the set
#sorted(set([w.lower() for w in text1]))

# %%
# This line makes the text into a set first and then on the set converts all words to lower case. Then sort the list
#sorted([w.lower() for w in set(text1)])

# %% [markdown]
# * 22 Find all the four-letter words in the Chat Corpus (text5). With the help of a frequency distribution (FreqDist), show these words in decreasing order of frequency.

# %%
four_letter_words = sorted([word for word in text5 if len(word) == 4])

# %%
sorted(FreqDist(four_letter_words).items(), key=lambda x:(x[1], x[0]), reverse=True)
# Out:
# [('JOIN', 1021),
#  ('PART', 1016),
#  ('that', 274),
#  ('what', 183),
#  ('here', 181),
#  ('....', 170),
#  ('have', 164),
#  ('like', 156),
#  ('with', 152),
#  ('chat', 142),
#  ('your', 137),
#  ('good', 130),
#  ('just', 125),
#  ('lmao', 107),
#  ('know', 103),
#  ('room', 98),
#  ('from', 92),
#  ('this', 86),
#  ('well', 81),
#  ('hiya', 78),
#  ('back', 78),
#  ('they', 77),
#  ('yeah', 75),
#  ('dont', 75),
#  ('want', 71),
#  ('love', 60),
#  ('some', 58),
#  ('guys', 58),
#  ('been', 57),
#  ('talk', 56),
#  ('nice', 52),
#  ('time', 50),
#  ('when', 48),
#  ('make', 44),
#  ('haha', 44),
#  ('need', 43),
#  ('girl', 43),
#  ('U122', 42),
#  ('MODE', 41),
#  ('will', 40),
#  ('then', 40),
#  ('much', 40),
#  ('over', 39),
#  ('work', 38),
#  ('were', 38),
#  ('take', 37),
#  ('song', 36),
#  ('U121', 36),
#  ('U115', 36),
#  ('seen', 35),
#  ('even', 35),
#  ('does', 35),
#  ('U156', 35),
#  ('U105', 35),
#  ('more', 34),
#  ('damn', 34),
#  ('only', 33),
# ...

# %% [markdown]
# * 23 Review the discussion of looping with conditions in 1.4. Use a combination of for and if statements to loop over the words of the movie script for Monty Python and the Holy Grail (text6) and print all the uppercase words, one per line.

# %%
[word for word in text6 if word.isupper()]
# Out:
# ['SCENE',
#  'KING',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'I',
#  'SOLDIER',
#  'ARTHUR',
#  'I',
#  'I',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'A',
#  'ARTHUR',
#  'SOLDIER',
#  'A',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'I',
#  'ARTHUR',
#  'I',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'I',
#  'ARTHUR',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SCENE',
#  'CART',
#  'MASTER',
#  'CUSTOMER',
#  'CART',
#  'MASTER',
#  'DEAD',
#  'PERSON',
#  'I',
#  'CART',
#  'MASTER',
#  'CUSTOMER',
#  'DEAD',
#  'PERSON',
#  'I',
#  'CART',
#  'MASTER',
#  'CUSTOMER',
#  'DEAD',
#  'PERSON',
#  'I',
#  'CART',
#  'MASTER',
#  'CUSTOMER',
#  'DEAD',
#  'PERSON',
#  'I',
#  'CUSTOMER',
#  'CART',
#  'MASTER',
#  'I',
#  'DEAD',
# ...

# %% [markdown]
# * 26 What does the following Python code do? sum([len(w) for w in text1]) Can you use it to work out the average word length of a text?

# %%
float(sum([len(w) for w in text1])) / len(text1)
# Out:
# 3.830411128023649

# %% [markdown]
# The average word ltngth is 3.8

# %% [markdown]
# * 27 Define a function called vocab_size(text) that has a single parameter for the text, and which returns the vocabulary size of the text.

# %%
def vocab_size(text):
    return len(set(text))

vocab_size(text6)
# Out:
# 2166

# %% [markdown]
# * 28 Define a function percent(word, text) that calculates how often a given word occurs in a text, and expresses the result as a percentage.

# %%
def percent(word,text):
    return float(text.count(word)) / len(text)

percent("a",text2)
# Out:
# 0.01443041193422614

# %% [markdown]
# # Chapter 2

# %% [markdown]
# Exercises: NLPP1e Chapter 2.
#
# * Solve exercise 4, 8, 11, 15, 16, 17, 18 in NLPP1e, section 2.8. As always, I recommend you write up your solutions nicely in a notebook.
#
# * Work through exercise 2.8.23 on Zipf's law. Zipf's law connects to a property of the Barabasi-Albert networks. Which one? Take a look at this article and write a paragraph or two describing other important instances of power-laws found on the internet.

# %% [markdown]
# ## 4
# * Read in the texts of the State of the Union addresses, using the state_union corpus reader. Count occurrences of men, women, and people in each document. What has happened to the usage of these words over time?

# %%
from nltk.corpus import state_union

# %%
state_union.words().count("men")
# Out:
# 228

# %%
state_union.words().count("women")
# Out:
# 141

# %%
state_union.words().count("people")
# Out:
# 1291

# %%
state_union.words("1945-Truman.txt").count("men")
# Out:
# 2

# %%
for file_id in state_union.fileids():
    men_count = state_union.words(file_id).count("men")
    women_count = state_union.words(file_id).count("women")
    people_count = state_union.words(file_id).count("people")
    print(men_count,women_count,people_count)
# Out:
# 2 2 10
# 12 7 49
# 7 2 12
# 4 1 22
# 2 1 15
# 6 2 15
# 8 2 9
# 3 0 17
# 2 0 15
# 4 0 26
# 2 2 30
# 5 2 11
# 2 1 19
# 4 1 11
# 2 0 10
# 6 0 10
# 6 2 10
# 0 0 3
# 8 5 12
# 3 1 3
# 7 0 16
# 11 3 14
# 12 1 35
# 11 1 25
# 4 0 17
# 5 2 6
# 2 0 23
# 1 0 31
# 1 0 7
# 0 0 9
# 0 0 19
# 0 0 13
# 3 1 18
# 2 1 17
# 0 1 26
# 0 1 15
# 1 2 11
# 1 1 11
# 1 1 17
# 3 7 19
# 3 5 23
# 1 1 12
# 2 2 14
# 1 0 24
# 1 0 16
# 2 3 13
# 3 2 9
# 2 2 13
# 7 7 13
# 4 4 26
# 1 2 45
# 1 1 63
# 1 3 73
# 2 3 40
# 1 2 30
# 2 2 22
# 2 3 22
# 5 6 41
# 3 3 14
# 1 2 12
# 3 5 14
# 6 4 33
# 6 8 21
# 8 11 18
# 7 7 22

# %% [markdown]
# The word "men" and "women" are accuring at the same rate in the more present time, previously "men" had a higher count

# %% [markdown]
# * 8 Define a conditional frequency distribution over the Names corpus that allows you to see which initial letters are more frequent for males vs. females (cf. 2.10).

# %%
from nltk.corpus import names
names.fileids()
# Out:
# ['female.txt', 'male.txt']

# %%
female = [name[:1] for name in names.words("female.txt")]
male = [name[:1] for name in names.words("male.txt")]

# %%
FreqDist(female).plot()

# %%
FreqDist(male).plot()

# %% [markdown]
# * 11 Investigate the table of modal distributions and look for other patterns. Try to explain them in terms of your own impressionistic understanding of the different genres. Can you find other closed classes of words that exhibit significant differences across different genres?

# %% [markdown]
# news: The reason why there are alot of will might be due to the fact that there are alot of statements and conclusions around some news fact.
#
#
# religion: I think might in this context is refering to power and probablility. The concepts in religion is often deterministic
#
#
# hobbies: Alot of "can" this is aimed at possibility from the readers point of view.
#
# science_fiction: Its hard to tell what why this distribution is accuring
#
# romance: Alot of "could", there might be alot of questions asked.
#
# humor: "could" this be true.

# %% [markdown]
# * 15 Write a program to find all words that occur at least three times in the Brown Corpus.

# %%
from nltk.corpus import brown

# %%
word_counts = [word for word,count in FreqDist(brown.words()).items() if count >= 3]

# %% [markdown]
# ### 16
# * Write a program to generate a table of lexical diversity scores (i.e. token/type ratios), as we saw in 1.1. Include the full set of Brown Corpus genres (nltk.corpus.brown.categories()). Which genre has the lowest diversity (greatest number of tokens per type)? Is this what you would have expected?

# %%
def lexical_diversity(text): 
    return float(len(text)) / len(set(text)) 

[(lexical_diversity(brown.words(categories=category)),category) for category in brown.categories()]
# Out:
# [(7.814063556457065, 'adventure'),
#  (9.396666847619565, 'belles_lettres'),
#  (6.22891809908999, 'editorial'),
#  (7.362717695119329, 'fiction'),
#  (8.570712626818237, 'government'),
#  (6.899455383326351, 'hobbies'),
#  (4.324297388877816, 'humor'),
#  (10.788777507562726, 'learned'),
#  (7.60525408536165, 'lore'),
#  (8.188054998567745, 'mystery'),
#  (6.98582742809504, 'news'),
#  (6.182174799937235, 'religion'),
#  (4.718757245536749, 'reviews'),
#  (8.284666351159489, 'romance'),
#  (4.475719146303742, 'science_fiction')]

# %% [markdown]
# Humor has a low diversity, in general i would expect humor to have low diversity because the audience might be broad is this case. And it might make sense to use the same establised vocabulary over and over in telling jokes. I would have expected science_fiction to have a larger diversity, because of the many different terms that exist in sci-fi.

# %% [markdown]
# ## 17
#
# Write a function that finds the 50 most frequently occurring words of a text that are not stopwords.

# %%
from nltk.corpus import stopwords

# %%
word_list = [word for word in text6 if word.lower() not in stopwords.words("english")]

# %%
freq_word_list = sorted(FreqDist(word_list).items(), key=lambda x:(x[1], x[0]), reverse=True)

# %%
freq_word_list[:50]
# Out:
# [(':', 1197),
#  ('.', 816),
#  ('!', 801),
#  (',', 731),
#  ("'", 421),
#  ('[', 319),
#  (']', 312),
#  ('ARTHUR', 225),
#  ('?', 207),
#  ('--', 148),
#  ('#', 127),
#  ('...', 118),
#  ('Oh', 110),
#  ('-', 88),
#  ('LAUNCELOT', 76),
#  ('1', 76),
#  ('GALAHAD', 69),
#  ('KNIGHT', 68),
#  ('FATHER', 63),
#  ('BEDEVERE', 61),
#  ('Well', 54),
#  ('HEAD', 54),
#  ('GUARD', 53),
#  ('Sir', 52),
#  ('VILLAGER', 47),
#  ('Ni', 47),
#  ('boom', 45),
#  ('ha', 42),
#  ('Yes', 42),
#  ('2', 42),
#  ('clop', 39),
#  ('ROBIN', 39),
#  ('away', 38),
#  ('witch', 37),
#  ('KNIGHTS', 37),
#  ('Arthur', 36),
#  ('Grail', 34),
#  ('us', 32),
#  ('one', 32),
#  ('Burn', 32),
#  ('BLACK', 32),
#  ('singing', 31),
#  ('mumble', 30),
#  ('TIM', 30),
#  ('squeak', 29),
#  ('music', 29),
#  ('FRENCH', 29),
#  ('got', 27),
#  ('Right', 27),
#  ('King', 27)]

# %% [markdown]
# ## 18
#
# * Write a program to print the 50 most frequent bigrams (pairs of adjacent words) of a text, omitting bigrams that contain stopwords.

# %%
bigram = nltk.bigrams(word_list)
freq_word_list = sorted(FreqDist(bigram).items(), key=lambda x:(x[1], x[0]), reverse=True)

# %%
freq_word_list
# Out:
# [(('ARTHUR', ':'), 217),
#  ((':', "'"), 96),
#  ((']', '['), 94),
#  ((':', 'Oh'), 82),
#  ((',', "'"), 82),
#  (('!', '['), 82),
#  (('Oh', ','), 79),
#  (('LAUNCELOT', ':'), 76),
#  (('1', ':'), 75),
#  (('.', 'ARTHUR'), 75),
#  (('#', '1'), 75),
#  (('GALAHAD', ':'), 69),
#  ((':', '['), 67),
#  (('FATHER', ':'), 63),
#  (('!', 'ARTHUR'), 63),
#  (('BEDEVERE', ':'), 61),
#  (('KNIGHT', ':'), 59),
#  ((':', 'Well'), 52),
#  ((':', ','), 52),
#  (('Well', ','), 50),
#  (('.', "'"), 49),
#  (('VILLAGER', '#'), 47),
#  (('#', '2'), 41),
#  (('2', ':'), 40),
#  (('ROBIN', ':'), 39),
#  ((':', 'Yes'), 38),
#  (('.', '['), 38),
#  (('Ni', '!'), 36),
#  (('boom', ']'), 35),
#  (('[', 'boom'), 34),
#  (('?', 'ARTHUR'), 34),
#  (('GUARD', '#'), 32),
#  (('BLACK', 'KNIGHT'), 32),
#  (('witch', '!'), 31),
#  ((':', '?'), 31),
#  (('!', "'"), 31),
#  (('[', 'singing'), 29),
#  (('HEAD', 'KNIGHT'), 29),
#  (('Burn', '!'), 29),
#  (('TIM', ':'), 28),
#  (('.', 'LAUNCELOT'), 27),
# ...

# %% [markdown]
# ## 23
# * Zipf's Law: Let f(w) be the frequency of a word w in free text. Suppose that all the words of a text are ranked according to their frequency, with the most frequent word first. Zipf's law states that the frequency of a word type is inversely proportional to its rank (i.e. f × r = k, for some constant k). For example, the 50th most common word type should occur three times as frequently as the 150th most common word type.
#     * Write a function to process a large text and plot word frequency against word rank using pylab.plot. Do you confirm Zipf's law? (Hint: it helps to use a logarithmic scale). What is going on at the extreme ends of the plotted line?
#     * Generate random text, e.g., using random.choice("abcdefg "), taking care to include the space character. You will need to import random first. Use the string concatenation operator to accumulate characters into a (very) long string. Then tokenize this string, and generate the Zipf plot as before, and compare the two plots. What do you make of Zipf's Law in the light of this?

# %%
# f(w) frequency of a word w in text
# f = count of frequncy
frequency = FreqDist(text1)

# %%
words = sorted(frequency.items(), key=lambda x:(x[1], x[0]), reverse=True)

# %%
counts = [count for word,count in words]
ranks = [num for num in range(len(words))]

# %%
plt.loglog(ranks,counts)

# %% [markdown]
# Zipf law holdes true for the word frequency by rank.
# On the plot it shows there is a power law distribution.
# In the extreem end of the plot the word frequency is 1. Therefore the line is not declining because there is no cases for wordfrequency below 1.

# %%
ranks[-5:]
# Out:
# [19312, 19313, 19314, 19315, 19316]

# %%
counts[-5:]
# Out:
# [1, 1, 1, 1, 1]

# %% [markdown]
# * Generate random text, e.g., using random.choice("abcdefg "), taking care to include the space character. You will need to import random first. Use the string concatenation operator to accumulate characters into a (very) long string. Then tokenize this string, and generate the Zipf plot as before, and compare the two plots. What do you make of Zipf's Law in the light of this?

# %%
import random

# %%
random.choice("abcfefg ")
# Out:
# 'a'

# %%
string = ""
for i in range(10):
    string += random.choice("abcdefg ")
string
# Out:
# 'dgf   fa d'

# %%
tokenized_string = string.split(" ")

# %%
tokenized_string
# Out:
# ['dgf', '', '', 'fa', 'd']
