# %%
import sys
import twitter
import json
from pprint import pprint

# %% [markdown]
# # 1.1

# %%
CONSUMER_KEY = 'CT570AzoIyp45MLPVaDRjdmcu'
CONSUMER_SECRET = 'nXAd7t5QXXxCydjR4sHVna6zzUO7JDBXv0ol7q1V93BwzuNIgT'
OAUTH_TOKEN = '852920447364673536-E4uDZjbajguzlrqT0DWXtsUt7cMVjak'
OAUTH_TOKEN_SECRET = 'tkhvyLtvOj7oWWelBEtJ9cf3W1oDBT9wn8zAIGSF8t5nA'

auth = twitter.oauth.OAuth(OAUTH_TOKEN, OAUTH_TOKEN_SECRET,
                           CONSUMER_KEY, CONSUMER_SECRET)

twitter_api = twitter.Twitter(domain='api.twitter.com', 
                              api_version='1.1',
                              auth=auth
                             )

# %% [markdown]
# # 1.2

# %%
WORLD_WOE_ID = 1 
US_WOE_ID = 23424977
DK_WOE_ID = 23424796

# Prefix id with the underscore for query string parameterization.
# Without the underscore, it's appended to the URL itself
world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)

dk_trends = twitter_api.trends.place(_id=DK_WOE_ID)

# %% [markdown]
# # 1.3

# %%
# Trending in denmark
json_dk_trends = json.dumps(dk_trends, indent=1)
print(json_dk_trends)
# Pretty print json
pprint(dk_trends)
# Out:
# [
#  {
#   "created_at": "2017-09-03T22:16:44Z",
#   "trends": [
#    {
#     "url": "http://twitter.com/search?q=%23Statsministrene",
#     "query": "%23Statsministrene",
#     "tweet_volume": null,
#     "name": "#Statsministrene",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23tyskvalg",
#     "query": "%23tyskvalg",
#     "tweet_volume": null,
#     "name": "#tyskvalg",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23sportfyn",
#     "query": "%23sportfyn",
#     "tweet_volume": null,
#     "name": "#sportfyn",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23CFforskpris",
#     "query": "%23CFforskpris",
#     "tweet_volume": null,
#     "name": "#CFforskpris",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23DHMasters",
#     "query": "%23DHMasters",
#     "tweet_volume": null,
#     "name": "#DHMasters",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Trump",
#     "query": "Trump",
#     "tweet_volume": 1737734,
#     "name": "Trump",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=Europe",
#     "query": "Europe",
#     "tweet_volume": 112685,
#     "name": "Europe",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23EULCS",
#     "query": "%23EULCS",
#     "tweet_volume": null,
#     "name": "#EULCS",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23f1dk",
#     "query": "%23f1dk",
#     "tweet_volume": null,
#     "name": "#f1dk",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23HBeredskab",
#     "query": "%23HBeredskab",
#     "tweet_volume": null,
#     "name": "#HBeredskab",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23handball",
#     "query": "%23handball",
#     "tweet_volume": null,
#     "name": "#handball",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23Copenhagen",
#     "query": "%23Copenhagen",
#     "tweet_volume": null,
#     "name": "#Copenhagen",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23nfldk",
#     "query": "%23nfldk",
#     "tweet_volume": null,
#     "name": "#nfldk",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23landsholdet",
#     "query": "%23landsholdet",
#     "tweet_volume": null,
#     "name": "#landsholdet",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23vmkval",
#     "query": "%23vmkval",
#     "tweet_volume": null,
#     "name": "#vmkval",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23USOpen",
#     "query": "%23USOpen",
#     "tweet_volume": 61989,
#     "name": "#USOpen",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23LV2017",
#     "query": "%23LV2017",
#     "tweet_volume": 17749,
#     "name": "#LV2017",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23indiegame",
#     "query": "%23indiegame",
#     "tweet_volume": null,
#     "name": "#indiegame",
#     "promoted_content": null
#    },
#    {
#     "url": "http://twitter.com/search?q=%23betdk",
#     "query": "%23betdk",
#     "tweet_volume": null,
#     "name": "#betdk",
#     "promoted_content": null
#    }
#   ],
#   "as_of": "2017-09-03T22:22:33Z",
#   "locations": [
#    {
#     "woeid": 23424796,
#     "name": "Denmark"
#    }
#   ]
#  }
# ]
# [{u'as_of': u'2017-09-03T22:22:33Z',
#   u'created_at': u'2017-09-03T22:16:44Z',
#   u'locations': [{u'name': u'Denmark', u'woeid': 23424796}],
#   u'trends': [{u'name': u'#Statsministrene',
#                u'promoted_content': None,
#                u'query': u'%23Statsministrene',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23Statsministrene'},
#               {u'name': u'#tyskvalg',
#                u'promoted_content': None,
#                u'query': u'%23tyskvalg',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23tyskvalg'},
#               {u'name': u'#sportfyn',
#                u'promoted_content': None,
#                u'query': u'%23sportfyn',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23sportfyn'},
#               {u'name': u'#CFforskpris',
#                u'promoted_content': None,
#                u'query': u'%23CFforskpris',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23CFforskpris'},
#               {u'name': u'#DHMasters',
#                u'promoted_content': None,
#                u'query': u'%23DHMasters',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23DHMasters'},
#               {u'name': u'Trump',
#                u'promoted_content': None,
#                u'query': u'Trump',
#                u'tweet_volume': 1737734,
#                u'url': u'http://twitter.com/search?q=Trump'},
#               {u'name': u'Europe',
#                u'promoted_content': None,
#                u'query': u'Europe',
#                u'tweet_volume': 112685,
#                u'url': u'http://twitter.com/search?q=Europe'},
#               {u'name': u'#EULCS',
#                u'promoted_content': None,
#                u'query': u'%23EULCS',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23EULCS'},
#               {u'name': u'#f1dk',
#                u'promoted_content': None,
#                u'query': u'%23f1dk',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23f1dk'},
#               {u'name': u'#HBeredskab',
#                u'promoted_content': None,
#                u'query': u'%23HBeredskab',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23HBeredskab'},
#               {u'name': u'#handball',
#                u'promoted_content': None,
#                u'query': u'%23handball',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23handball'},
#               {u'name': u'#Copenhagen',
#                u'promoted_content': None,
#                u'query': u'%23Copenhagen',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23Copenhagen'},
#               {u'name': u'#nfldk',
#                u'promoted_content': None,
#                u'query': u'%23nfldk',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23nfldk'},
#               {u'name': u'#landsholdet',
#                u'promoted_content': None,
#                u'query': u'%23landsholdet',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23landsholdet'},
#               {u'name': u'#vmkval',
#                u'promoted_content': None,
#                u'query': u'%23vmkval',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23vmkval'},
#               {u'name': u'#USOpen',
#                u'promoted_content': None,
#                u'query': u'%23USOpen',
#                u'tweet_volume': 61989,
#                u'url': u'http://twitter.com/search?q=%23USOpen'},
#               {u'name': u'#LV2017',
#                u'promoted_content': None,
#                u'query': u'%23LV2017',
#                u'tweet_volume': 17749,
#                u'url': u'http://twitter.com/search?q=%23LV2017'},
#               {u'name': u'#indiegame',
#                u'promoted_content': None,
#                u'query': u'%23indiegame',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23indiegame'},
#               {u'name': u'#betdk',
#                u'promoted_content': None,
#                u'query': u'%23betdk',
#                u'tweet_volume': None,
#                u'url': u'http://twitter.com/search?q=%23betdk'}]}]

# %% [markdown]
# # Intersections between trends 1.4

# %%
world_trends_set = set([trend['name'] for trend in world_trends[0]['trends']])

us_trends_set = set([trend['name'] for trend in us_trends[0]['trends']]) 

common_trends = world_trends_set.intersection(us_trends_set)

print common_trends
# Out:
# set([u'John Ashbery', u'Sevastova', u'#TVDuell', u'#TwinPeaksFinale', u'Steely Dan', u'#80sMeWouldSay', u'#SundayFunday', u'#RuinTvShowsInOneLetter'])

# %% [markdown]
# # 1.5

# %%
# XXX: Set this variable to a trending topic, 
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter.

q = '#Unity' 

count = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=count)

statuses = search_results['statuses']


# Iterate through 5 more batches of results by following the cursor

for _ in range(5):
    print "Length of statuses", len(statuses)
    try:
        next_results = search_results['search_metadata']['next_results']
    except KeyError, e: # No more results when next_results doesn't exist
        break
        
    # Create a dictionary from next_results, which has the following form:
    # ?max_id=313519052523986943&q=NCAA&include_entities=1
    kwargs = dict([ kv.split('=') for kv in next_results[1:].split("&") ])
    
    search_results = twitter_api.search.tweets(**kwargs)
    statuses += search_results['statuses']

# Show one sample search result by slicing the list...
print json.dumps(statuses[0], indent=1)
# Out:
# Length of statuses 100
# Length of statuses 200
# Length of statuses 200
# {
#  "contributors": null,
#  "truncated": false,
#  "text": "RT @DKGart: Environemnt Progress, city street, 50s, needs more doodads still. #gameart #Unity #substancePainter #SubstanceDesigner #indiede\u2026",
#  "is_quote_status": false,
#  "in_reply_to_status_id": null,
#  "id": 904470939357790208,
#  "favorite_count": 0,
#  "entities": {
#   "symbols": [],
#   "user_mentions": [
#    {
#     "id": 448664881,
#     "indices": [
#      3,
#      10
#     ],
#     "id_str": "448664881",
#     "screen_name": "DKGart",
#     "name": "Devin"
#    }
#   ],
#   "hashtags": [
#    {
#     "indices": [
#      78,
#      86
#     ],
#     "text": "gameart"
#    },
#    {
#     "indices": [
#      87,
#      93
#     ],
#     "text": "Unity"
#    },
#    {
#     "indices": [
#      94,
#      111
#     ],
#     "text": "substancePainter"
#    },
#    {
#     "indices": [
#      112,
#      130
#     ],
#     "text": "SubstanceDesigner"
#    }
#   ],
#   "urls": []
#  },
#  "retweeted": false,
#  "coordinates": null,
#  "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#  "in_reply_to_screen_name": null,
#  "in_reply_to_user_id": null,
#  "retweet_count": 1,
#  "id_str": "904470939357790208",
#  "favorited": false,
#  "retweeted_status": {
#   "contributors": null,
#   "truncated": true,
#   "text": "Environemnt Progress, city street, 50s, needs more doodads still. #gameart #Unity #substancePainter\u2026 https://t.co/jZX1DdKvmh",
#   "is_quote_status": false,
#   "in_reply_to_status_id": null,
#   "id": 900989867038986240,
#   "favorite_count": 3,
#   "entities": {
#    "symbols": [],
#    "user_mentions": [],
#    "hashtags": [
#     {
#      "indices": [
#       66,
#       74
#      ],
#      "text": "gameart"
#     },
#     {
#      "indices": [
#       75,
#       81
#      ],
#      "text": "Unity"
#     },
#     {
#      "indices": [
#       82,
#       99
#      ],
#      "text": "substancePainter"
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/jZX1DdKvmh",
#      "indices": [
#       101,
#       124
#      ],
#      "expanded_url": "https://twitter.com/i/web/status/900989867038986240",
#      "display_url": "twitter.com/i/web/status/9\u2026"
#     }
#    ]
#   },
#   "retweeted": false,
#   "coordinates": null,
#   "source": "<a href=\"http://twitter.com\" rel=\"nofollow\">Twitter Web Client</a>",
#   "in_reply_to_screen_name": null,
#   "in_reply_to_user_id": null,
#   "retweet_count": 1,
#   "id_str": "900989867038986240",
#   "favorited": false,
#   "user": {
#    "follow_request_sent": false,
#    "has_extended_profile": false,
#    "profile_use_background_image": true,
#    "default_profile_image": false,
#    "id": 448664881,
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#    "verified": false,
#    "translator_type": "none",
#    "profile_text_color": "333333",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/835756335211819010/YriyBRqL_normal.jpg",
#    "profile_sidebar_fill_color": "DDEEF6",
#    "entities": {
#     "url": {
#      "urls": [
#       {
#        "url": "https://t.co/GoFON7T33w",
#        "indices": [
#         0,
#         23
#        ],
#        "expanded_url": "https://www.artstation.com/artist/devingaviria",
#        "display_url": "artstation.com/artist/devinga\u2026"
#       }
#      ]
#     },
#     "description": {
#      "urls": []
#     }
#    },
#    "followers_count": 156,
#    "profile_sidebar_border_color": "C0DEED",
#    "id_str": "448664881",
#    "profile_background_color": "C0DEED",
#    "listed_count": 14,
#    "is_translation_enabled": false,
#    "utc_offset": -21600,
#    "statuses_count": 139,
#    "description": "Game Artist, Digital sculptor, Visual designer",
#    "friends_count": 224,
#    "location": "Tempe, AZ",
#    "profile_link_color": "1DA1F2",
#    "profile_image_url": "http://pbs.twimg.com/profile_images/835756335211819010/YriyBRqL_normal.jpg",
#    "following": false,
#    "geo_enabled": false,
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/448664881/1471374652",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#    "screen_name": "DKGart",
#    "lang": "en",
#    "profile_background_tile": false,
#    "favourites_count": 41,
#    "name": "Devin",
#    "notifications": false,
#    "url": "https://t.co/GoFON7T33w",
#    "created_at": "Wed Dec 28 07:17:07 +0000 2011",
#    "contributors_enabled": false,
#    "time_zone": "Mazatlan",
#    "protected": false,
#    "default_profile": true,
#    "is_translator": false
#   },
#   "geo": null,
#   "in_reply_to_user_id_str": null,
#   "possibly_sensitive": false,
#   "lang": "en",
#   "created_at": "Fri Aug 25 07:54:58 +0000 2017",
#   "in_reply_to_status_id_str": null,
#   "place": null,
#   "metadata": {
#    "iso_language_code": "en",
#    "result_type": "recent"
#   }
#  },
#  "user": {
#   "follow_request_sent": false,
#   "has_extended_profile": true,
#   "profile_use_background_image": true,
#   "default_profile_image": false,
#   "id": 48597549,
#   "profile_background_image_url_https": "https://pbs.twimg.com/profile_background_images/491421661975945216/p5kgPqbA.png",
#   "verified": false,
#   "translator_type": "none",
#   "profile_text_color": "333333",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/876243224238505984/HnKKy_3B_normal.jpg",
#   "profile_sidebar_fill_color": "D1D1AA",
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "followers_count": 2579,
#   "profile_sidebar_border_color": "FFFFFF",
#   "id_str": "48597549",
#   "profile_background_color": "324559",
#   "listed_count": 972,
#   "is_translation_enabled": false,
#   "utc_offset": 36000,
#   "statuses_count": 136779,
#   "description": "",
#   "friends_count": 2818,
#   "location": "",
#   "profile_link_color": "557294",
#   "profile_image_url": "http://pbs.twimg.com/profile_images/876243224238505984/HnKKy_3B_normal.jpg",
#   "following": false,
#   "geo_enabled": false,
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/48597549/1405994234",
#   "profile_background_image_url": "http://pbs.twimg.com/profile_background_images/491421661975945216/p5kgPqbA.png",
#   "screen_name": "blinkok",
#   "lang": "en",
#   "profile_background_tile": false,
#   "favourites_count": 4708,
#   "name": "blink",
#   "notifications": false,
#   "url": null,
#   "created_at": "Fri Jun 19 03:37:13 +0000 2009",
#   "contributors_enabled": false,
#   "time_zone": "Sydney",
#   "protected": false,
#   "default_profile": false,
#   "is_translator": false
#  },
#  "geo": null,
#  "in_reply_to_user_id_str": null,
#  "lang": "en",
#  "created_at": "Sun Sep 03 22:27:30 +0000 2017",
#  "in_reply_to_status_id_str": null,
#  "place": null,
#  "metadata": {
#   "iso_language_code": "en",
#   "result_type": "recent"
#  }
# }

# %%
# Number of retweets
retweet_count = [status["retweet_count"] for status in statuses]

#Index of max retweet count

max_value = max(retweet_count)
max_index = retweet_count.index(max_value)
most_popular_tweet = statuses[max_index]["text"]

# This was the most retweeted tweet
most_popular_tweet
# Out:
# u"RT @DavidYankovich: .@ironstache is the right person for the job. That's why I'm proud to put my full support behind him #Unity #FirePaulRy\u2026"
